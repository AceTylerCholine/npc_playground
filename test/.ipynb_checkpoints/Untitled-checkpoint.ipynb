# %%
import pickle
import multirecording_spikeanalysis as spike
import pandas as pd
import numpy as np

# %%
rcecollection = spike.EphysRecordingCollection(r'.\export')
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# 20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec
# Please assign event dictionaries to each recording
# as recording.event_dict
# event_dict = {event name(str): np.array[[start(ms), stop(ms)]...]
# Please assign subjects to each recording as recording.subject

# %%
label_timestamps = pickle.load(open('recording_to_label_to_timestamps 1.pkl', 'rb'))

# %%
label_timestamps
# Out:
# {'20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged': {'lose': array([[ 176337,  186337],
#          [ 291337,  301336],
#          [ 381336,  391336],
#          [ 436336,  446336],
#          [ 486336,  496336],
#          [ 581336,  591336],
#          [ 656336,  666336],
#          [ 761336,  771336],
#          [ 811336,  821336],
#          [ 891336,  901336],
#          [ 956336,  966336],
#          [1021336, 1031336],
#          [1071336, 1081336]], dtype=int64),
#   'rewarded': array([[1856335, 1866335],
#          [1916335, 1926335],
#          [1971335, 1981335],
#          [2036335, 2046335],
#          [2091334, 2101334],
#          [2141334, 2151334],
#          [2191334, 2201334],
#          [2296334, 2306334],
#          [2416334, 2426334],
#          [2536334, 2546334],
#          [2646334, 2656334],
#          [2731334, 2741334],
#          [2851334, 2861334],
#          [2911334, 2921334],
#          [2976334, 2986333],
# ...

# %%
rcecollection.collection['20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec'] = label_timestamps['20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged']

# %%
spike.get_event_lengths()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 spike.get_event_lengths()
#
# TypeError: get_event_lengths() missing 1 required positional argument: 'events'

# %%
omd1s11 = rcecollection.collection['20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec']

# %%
spike.get_event_lengths(spike
